# %%
import pandas as pd

# %%
 dataframe1 = pd.read_excel('../file/All_CSV_file_Data.xlsx')

# %%
dataframe1
# Out:
#      PDU  CLIENT_ID  LN_WITH_OR_WITHOUT_CYP  AUTH_MECH_NAME  SEC_POLICY  \
# 0      0         16                       1               0           0
# 1      1         16                       1               0           0
# 2      1         16                       1               0           0
# 3      4         16                       1               0           0
# 4      0         48                       3               2           2
# ..   ...        ...                     ...             ...         ...
# 329    1         32                       3               1           1
# 330    1         32                       3               1           1
# 331    1         32                       3               1           1
# 332    1         32                       3               1           1
# 333    4         32                       3               1           1
#
#      DEDICATED_KEY  CID                 LN  AID_ID_OR_METHOD_INDEX EXTRA  \
# ...
